# %%
"""
Miscellaneous non-normalizing data transformations on AnnData objects
"""
import os
import gzip
import math
import random
import numpy as np
import pandas as pd
from typing import Callable, Dict, List, NamedTuple, Optional, Tuple, Union
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
#from anndata import AnnData
#from scipy.sparse import csr_matrix
from typing_extensions import Literal

# %%
import sys
sys.path.append("..")
from tools import Enrichment_around_TSS,Uniform_Distribution_table

# %%
a=Uniform_Distribution_table

# %%
a
# Out:
# <function tools.ref_Uniform_Distribution.Uniform_Distribution_table(path: str = '..\\tools/Uniform_Distribution/freq_df_2.8wx1w_cutoff.csv', exe: Union[bool, NoneType] = True) -> pandas.core.frame.DataFrame>

# %%
b=Uniform_Distribution_table(exe=True)

# %%
b
# Out:
#        frag_num_100k  frag_num_1k_max    freq  freq_sum  freq_sum_cutoff
# 0                  1                1  1.0000    1.0000             True
# 1                  2                1  0.9905    1.0000             True
# 2                  3                1  0.9686    1.0000             True
# 3                  4                2  0.0577    0.0580             True
# 4                  5                2  0.0952    0.0960             True
# ...              ...              ...     ...       ...              ...
# 27995          27996              336  0.0118    0.0571             True
# 27996          27997              336  0.0089    0.0586             True
# 27997          27998              336  0.0093    0.0585             True
# 27998          27999              336  0.0102    0.0598             True
# 27999          28000              336  0.0089    0.0570             True
#
# [28000 rows x 5 columns]
